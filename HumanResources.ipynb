# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
train_data = pd.read_csv("hr_train.csv")

# %%
train_data.head()
train_data.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# type                     0
# dtype: int64

# %%
train_data

# %%
train_data['sales'].unique(
)
# Out:
# array(['sales', 'technical', 'product_mng', 'marketing', 'IT', 'RandD',
#        'hr', 'accounting', 'support', 'management'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
train_data['type'] = 'train'

# %%
# test_data = pd.read_csv('hr_test.csv')

# %%
# test_data['type'] = 'test'

# %%
train_data
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.42             0.46               2
# 1                    0.66             0.77               2
# 2                    0.55             0.49               5
# 3                    0.22             0.88               4
# 4                    0.20             0.72               6
# ...                   ...              ...             ...
# 10494                0.82             0.84               3
# 10495                0.85             0.81               3
# 10496                0.32             0.95               5
# 10497                0.51             0.76               4
# 10498                0.80             0.68               4
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       150                   3              0     1
# 1                       171                   2              0     0
# ...

# %%
# test_data['left'] = ""

# %%
# total = pd.concat([train_data,test_data], axis=0)

# %%
# total
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 0                   0.42             0.46               2
# 1                   0.66             0.77               2
# 2                   0.55             0.49               5
# 3                   0.22             0.88               4
# 4                   0.20             0.72               6
# ...                  ...              ...             ...
# 4495                0.88             0.61               4
# 4496                0.11             0.85               7
# 4497                1.00             0.88               4
# 4498                0.92             0.98               3
# 4499                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident left  \
# 0                      150                   3              0    1
# 1                      171                   2              0    0
# ...

# %%
# total.rename(columns = {'sales':'dept'}, inplace = True) 
# del total['dept']

# %%
# from sklearn.preprocessing import LabelEncoder
# deptle = LabelEncoder()
# dept_labels = deptle.fit_transform(total['dept'])
# dept_mappings = {index: label for index, label in 
#                   enumerate(deptle.classes_)}
# dept_mappings

# %%
# total['deptlabel'] = dept_labels

# %%
# y = pd.get_dummies(total.dept, prefix='dept')
# print(y.head())

# %%
# y

# %%
# total = pd.concat([total,y], axis=1)

# %%
total
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 0                   0.42             0.46               2
# 1                   0.66             0.77               2
# 2                   0.55             0.49               5
# 3                   0.22             0.88               4
# 4                   0.20             0.72               6
# ...                  ...              ...             ...
# 4495                0.88             0.61               4
# 4496                0.11             0.85               7
# 4497                1.00             0.88               4
# 4498                0.92             0.98               3
# 4499                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident left  \
# 0                      150                   3              0    1
# 1                      171                   2              0    0
# ...

# %%
total["salary"].unique()
# Out:
# array(['medium', 'high', 'low'], dtype=object)

# %%
total
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 0                   0.42             0.46               2
# 1                   0.66             0.77               2
# 2                   0.55             0.49               5
# 3                   0.22             0.88               4
# 4                   0.20             0.72               6
# ...                  ...              ...             ...
# 4495                0.88             0.61               4
# 4496                0.11             0.85               7
# 4497                1.00             0.88               4
# 4498                0.92             0.98               3
# 4499                0.37             0.52               2
#
#       average_montly_hours  time_spend_company  Work_accident left  \
# 0                      150                   3              0    1
# 1                      171                   2              0    0
# ...

# %%
# total = total.drop(['salary_label'], axis = 1)

# %%
total.loc[total['salary'] == "high", 'salary_label'] = int(2)
total.loc[total['salary'] == "medium", 'salary_label'] = int(1)
total.loc[total['salary'] == "low", 'salary_label'] = int(0)

# %%
total['salary_label'] = total['salary_label'].astype('int64')

# %%
total['salary_label'] = total['salary_label'].astype('category')
total['Work_accident'] = total['Work_accident'].astype('category')
total['left'] = total['left'].astype('int')
total['promotion_last_5years'] = total['promotion_last_5years'].astype('category')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-7fa3240bf6ac> in <module>
#       1 total['salary_label'] = total['salary_label'].astype('category')
#       2 total['Work_accident'] = total['Work_accident'].astype('category')
# ----> 3 total['left'] = total['left'].astype('int')
#       4 total['promotion_last_5years'] = total['promotion_last_5years'].astype('category')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5872         else:
#    5873             # else, only a single dtype is given
# -> 5874             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5875             return self._constructor(new_data).__finalize__(self, method="astype")
#    5876
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
# ...

# %%
del total['salary']

# %%
total.dtypes

# %%
total.head()

# %%
trainfinal = total[total['type'] == "train"]

# %%
testfinal = total[total['type'] == "test"]

# %%
trainfinal = trainfinal.drop(['type'], axis = 1)

# %%
testfinal=testfinal.drop(["type"], axis = 1)

# %%
trainfinal

# %%
y_train = trainfinal['left']
x_train = trainfinal.drop(['left'], axis = 1)

# %%
y_train.unique()

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain, Xval, Ytrain, Yval = train_test_split(x_train, y_train, test_size=0.25, random_state=1)

# %%
Yval = Yval.astype('int')

# %%
Xtrain

# %%
Ytrain

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
rfm = RandomForestClassifier(bootstrap=True)
etc = ExtraTreesClassifier()
# rfm.fit(Xtrain, Ytrain)
etc.fit(Xtrain, Ytrain)
y_predrfm = rfm.predict(Xval)

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Yval, y_predrfm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-7f5874a8c91a> in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 confusion_matrix(Yval, y_predrfm)
#
# NameError: name 'Yval' is not defined
